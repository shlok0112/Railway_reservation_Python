# %%
sqr =lambda a:a*a
print(sqr(5))
# Out:
# 25

# %%
l1= [5,6,7,8,9,10]
l2 = list(map(lambda l1:l1**2 ,l1))
print(l2)
# Out:
# [25, 36, 49, 64, 81, 100]

# %% [raw]
# # lambda - one line anonymous function
# # map() - apply function on each list member
# # filter() - filters data from list
# # zip() - combine two list member
# # enumerate() - return index + value
# # list() - Convert data in list(type casting)
# # print() - display the output on console
