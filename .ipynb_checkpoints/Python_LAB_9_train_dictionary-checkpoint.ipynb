# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Source": "Mumbai",
    "Destination": "Delhi",
    "Available_Seats": 120
}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train_Number"])
print("Train Name:", train["Train_Name"])
print("Source Station:", train["Source"])
print("Destination Station:", train["Destination"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Information:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available_Seats': 120}
#
# Train Number: 12951
# Train Name: Mumbai Rajdhani Express
# Source Station: Mumbai
# Destination Station: Delhi
# Available Seats: 120

# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Available_Seats": 120
}

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 120}

# %%
print("Train Name:", train["Train_Name"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Name: Mumbai Rajdhani Express
# Available Seats: 120

# %%
train["Available_Seats"] = 95
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
train.update({"Platform": 4})
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95, 'Platform': 4}

# %%
train.pop("Platform")
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
print("\nUpdated Train Record:")
print(train)
# Out:
# Updated Train Record:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
train.keys()
# Out:
# dict_keys(['Train_Number', 'Train_Name', 'Source', 'Destination', 'Available_Seats'])

# %%
train.values()
# Out:
# dict_values([12951, 'Mumbai Rajdhani Express', 'Mumbai', 'Delhi', 120])

# %%
student = {
            "S_id":[101,102,103,104,105],
            "S_name":["Pranit","Shlok","Kirtan","Vedang","Atharva"],
            "S_marks":[40,100,35,89,72]}

# %%
student.keys()
# Out:
# dict_keys(['S_id', 'S_name', 'S_marks'])

# %%
student.values()
# Out:
# dict_values([[101, 102, 103, 104, 105], ['Pranit', 'Shlok', 'Kirtan', 'Vedang', 'Atharva'], [40, 100, 35, 89, 72]])

# %%
student["S_id"][4]
# Out:
# 105

# %%
student["S_name"][2]
# Out:
# 'Kirtan'

# %%
#Dictionary key->List->Index->Individual Values
#Example:- 
#Student["S_marks"][3]

# %%
student_2 = student.copy()

# %%
print(student_2)
# Out:
# {'S_id': [101, 102, 103, 104, 105], 'S_name': ['Pranit', 'Shlok', 'Kirtan', 'Vedang', 'Atharva'], 'S_marks': [40, 100, 35, 89, 72]}

# %%
student.items()
# Out:
# dict_items([('S_id', [101, 102, 103, 104, 105]), ('S_name', ['Pranit', 'Shlok', 'Kirtan', 'Vedang', 'Atharva']), ('S_marks', [40, 100, 35, 89, 72])])
